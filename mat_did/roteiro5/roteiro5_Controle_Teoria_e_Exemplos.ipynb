# %% [markdown]
# ## Widgets(componentes)

# %% [markdown]
# Quando se está ploando gráficos em python, é as vezes interessante que se possa alterar parâmetros na equação para se observar como ela afeta a saída do programa.
#
# Porém não é conveniente que seja necessário voltar ao código, alterar os parâmetros, executar o código e esperar que se obtenha uma resposta, principalmente em códigos em que o tempo de resposta pode chegar aos segundos. Por isso o pacote ```ipywidgets``` pode ser muito interessante

# %% [markdown]
# O pacote ```ipywidgets ``` é uma biblioteca Python desenvolvida para criar interfaces gráficas interativas diretamente em ambientes computacionais baseados em notebooks, como o Jupyter Notebook e o JupyterLab

# %% [markdown]
# Seu principal objetivo é permitir que o usuário interaja com programas e visualizações de maneira dinâmica, sem a necessidade de desenvolver interfaces complexas utilizando ferramentas externas.

# %% [markdown]
# A biblioteca fornece diversos componentes gráficos, chamados de widgets, que possibilitam modificar parâmetros de programas enquanto eles estão em execução, tornando a análise de dados, simulações matemáticas e experimentos computacionais muito mais intuitivos.

# %% [markdown]
# ### 1 Widget-sliders (Componentes deslizantes)

# %% [markdown]
# Os sliders(deslizantes) são uma das formas mais intuitivas de se modificar parâmetros a partir de interfaes gráficas, pois permitem que se altere valores de forma bem controlada e dentro de uma faixa definida com intervalos também alteráveis.

# %% [markdown]
# Aqui está um exemplo:

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

x = np.linspace(0, 10, 1000)

def atualizar(amplitude, frequencia, fase):         #atualizar é a função que permite que os valores sejam constantemente modificados.
    y = amplitude * np.sin(frequencia * x + fase)   #Defiindo uma seóide

    plt.figure(figsize=(8,4))                       #Plotando Gráfico de uma senóide
    plt.plot(x, y)
    plt.title("Senoide com ajuste em tempo real")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.grid(True)
    plt.ylim(-10, 10)
    plt.show()

# Criação dos sliders
slider_amplitude = widgets.FloatSlider(         #Criando um slider para valores reais
    value=1,                                    #Valor inicial
    min=0,                                      #Valor mínimo
    max=10,                                     #Valor máximo
    step=0.1,                                   #Tamanho dos intervalos
    description='Amplitude'                     #Nome quse dará ao slider
)

slider_frequencia = widgets.FloatSlider(
    value=1,
    min=0.1,
    max=10,
    step=0.1,
    description='Freq.'
)

slider_fase = widgets.FloatSlider(
    value=0,
    min=0,
    max=2*np.pi,
    step=0.1,
    description='Fase'
)

# Liga os sliders à função
widgets.interactive(                    #Função que relaciona as variaeis do valor do slider 
    atualizar,                          #com as variáveis da equação
    amplitude=slider_amplitude,
    frequencia=slider_frequencia,
    fase=slider_fase
)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Amplitude', max=10.0), FloatSlider(value=1.0, descri…

# %% [markdown]
# Mas o slider não é limitado a horizontal, se pode fazer sliders verticais também mudando sua orientação.

# %%
widgets.FloatSlider(value=5, min=0, max=10, orientation='vertical')
# Out:
# FloatSlider(value=5.0, max=10.0, orientation='vertical')

# %% [markdown]
# Porém não se tem somente esses tipos de sliders, também se tem o ```IntSlider``` que representa sliders para valores inteiros, o ```FloatLogSlider``` que representa valores na forma de logarítimo e ```RangeSlider``` tanto para valores inteiros e reais que representam uma faixa de valores

# %% [markdown]
# ### Exemplos:

# %%
#Slider para valores inteiros

widgets.IntSlider(
    value=5,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,             #Permite o slider ser disabilitado e abilitado
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
# Out:
# IntSlider(value=5, continuous_update=False, description='Test:', max=10)

# %%
#Slider para valores logarítimos

widgets.FloatLogSlider(
    value=10,
    base=10,
    min=-10, # min exponent of base
    max=10, # max exponent of base
    step=0.1, # exponent step
    description='Log Slider'
)
# Out:
# FloatLogSlider(value=10.0, description='Log Slider', max=10.0, min=-10.0)

# %%
#Slider para faia de valores inteiros

widgets.IntRangeSlider(
    value=[5, 7],
    min=0,
    max=10,
    step=1,
    description='Range Int:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)
# Out:
# IntRangeSlider(value=(5, 7), continuous_update=False, description='Range Int:', max=10)

# %%
#Slider para faia de valores reais

widgets.FloatRangeSlider(
    value=[5, 7.5],
    min=0,
    max=10.0,
    step=0.1,
    description='Range Float:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatRangeSlider(value=(5.0, 7.5), continuous_update=False, description='Range Float:', max=10.0, readout_form…

# %% [markdown]
# #### Fontes:
# 1. https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html
