# %% [markdown]
# # <span style="color: #2BF507; background-color: #024E4C; padding: 15px">Roteiro 2 - Introdução à Linguagem Python </span>

# %% [markdown]
# ## Conteúdo
#  - Introdução à Linguagem Python - Sintaxe Básica e Pacotes NumPy e Matplotlib

# %% [markdown]
# ### 7 - Mais Estruturas de Dados: Dicionários

# %% [markdown]
# São estruturas de dados nativas, mutáveis e que armazenam pares ordenados de `chave:valor`, tal como **verbetes** e **significados/sinônimos** de um dicionário físico.

# %%
# Exemplo 1: Perfil de usuário
usuario = {
    "nome": "João da Silva",
    "idade": 28,
    "email": "jds@email.com",
    "ativo": True
}
print(usuario)
# Out:
# {'nome': 'João da Silva', 'idade': 28, 'email': 'jds@email.com', 'ativo': True}

# %% [markdown]
# Os **dicionários** em Python funcionam como tabelas *hash* usadas em busca rápida, permitindo acesso, inserção e exclusão eficientes dos pares `chave:valor`. As **chaves** devem ser constantes únicas e imutáveis (strings, números, tuplas), enquanto os **valores** podem ser de qualquer tipo de dado.
#
# Os **dicionários** são também chamados de “memória associativa” ou “vetor associativo” em outras linguagens de programação. Diferentemente das sequências (listas, tuplas, vetores etc.) que são indexadas por valores numéricos inteiros, os dicionários são indexados por `chaves` (*keys*) que podem ser de qualquer tipo imutável (como strings e inteiros).
#
# #### 7.1 Características
# * Mutabilidade: Os dicionários podem ser alterados, adicionados, removidos ou modificados após a sua criação.
# * Mapeamento: Acesso a valores através de chaves únicas, índices não numéricos.
# * Performance: A busca de um item é extremamente rápida, ideal para armazenar grandes coleções de dados estruturados.
# * Criação: Utiliza-se um par de chaves `{}` e dois pontos para separar `chaves` e `valores`, por exemplo: `meu_dic = {"nome": "Ana", "idade": 25, "altura":1.77, "estado_civ":"solteira"}`
# * Métodos Comuns:
#
#     `dic = {}`: cria um dicionário vazio.
#     `dic[chave] = valor`: Adiciona ou atualiza um item no dicionário.
#     `del dic[chave]`: Remove do dicionário o item descrito pela 'chave'.
#     `dic.keys()`: Retorna todas as chaves do dicionário.
#     `dic.values()`: Retorna todos os valores do dicionário.
#     `dic.items()`: Retorna todos os pares (chave:valor) do dicionário.

# %%
# Exemplo 2:
meu_dic = {"nome": "Ana", "idade": 25, "altura":1.77, "estado_civ":"solteira"}
print(meu_dic.keys())
print(meu_dic["nome"],meu_dic["altura"])
# Out:
# dict_keys(['nome', 'idade', 'altura', 'estado_civ'])
# Ana 1.77

# %%
# Exemplo 3:
usuario = {"id": 1, "nome": "João", "função": "admin"}
# Acessa um valor
print(usuario["nome"])
# Adiciona/Modifica item(ns)
usuario["ativo"] = True
usuario["id"] = 2
# Verifica
if "função" in usuario:
    print("Função definida!")
# Out:
# João
# Função definida!
# vale para valores tbm...

# %% [markdown]
# ### 8 - Funções do Usuário

# %% [markdown]
# Modularizar um código é o processo de dividir um programa grande e complexo em partes menores, organizadas e reutilizáveis, conhecidas como **módulos** (funções e sub-rotinas). Isso facilita a manutenção, o teste e a leitura do código, permitindo que alterações sejam feitas em uma parte do código sem afetar o todo.
#
# #### 8.1 Conceitos de Modularização com Funções do Usuário
# * **Função do Usuário** (`def`)
#     Função é um bloco de código que realiza uma tarefa específica. Ao se definir uma função do usuário, pode-se utilizá-la (chamá-la) em vários pontos do código.
#     **Sintaxe**: Usa-se a palavra-chave `def` seguida do nome da função e de parâmetro(s) entre parênteses ().
#     **Parâmetros**: Dados que a função recebe para processar, descritos entre parênteses ().
#     **Retorno** (`return`):  Retorna um valor (escalar, vetor etc.) que a função devolve ao programa chamador.

# %%
# Exemplo 1: função para cálculo da área de um retangulo. Recebe dois parâmetros: base e altura.
def area_retangulo(base, altura):
    """ Calcula a área de um retângulo 
        base  : comprimento da base do retângulo
        altura: comprimento da altura do retângulo
    """
    area = base * altura
    return area

# Chamando a função area_retangulo()
area_do_retangulo1 = area_retangulo(10, 5)
area_do_retangulo2 = area_retangulo(3, 4)
print(f"Áreas: {area_do_retangulo1} m\u00b2, {area_do_retangulo2} m\u00b2")
# Out:
# Áreas: 50 m², 12 m²

# %% [markdown]
# ### 9 - Escrevendo o Código com Classes

# %% [markdown]
# Escrever código com **Classes** em Python é a base da **Programação Orientada a Objetos** (POO). Ela permite organizar o código agrupando dados (atributos) e comportamentos (métodos) em unidades lógicas, chamadas de **classes**.
#
# #### 9.1 Estrutura de uma Classe
# A estrutura envolve o uso da palavra-chave `class`, seguida pelo nome da classe (em geral se usa **PascalCase** - convenção de nomenclatura, na qual a primeira letra de cada palavra num nome composto é maiúscula, sem espaços ou caracteres especiais. Ex.: `MinhaClasseExemplo`) e o método **construtor** `__init__`, que define os atributos iniciais do objeto.
#
# **Exemplo**: Classe de Carros

# %%
# Exemplo 1
class Carro:
    
    def __init__(self, marca, modelo, ano=2024):                       # Método construtor (inicializa os atributos)
        self.marca = marca      # Atributo
        self.modelo = modelo    # Atributo
        self.ano = ano          # Atributo
        self.velocidade = 0     # Atributo com valor padrão (default)

    def acelerar(self):                                                # Método (comportamento)
        self.velocidade += 10
        print(f"O {self.modelo} acelerou para {self.velocidade} km/h")

    def exibir_info(self):                                             # Método para exibir informações
        print(f"Carro: {self.marca} {self.modelo}, Ano: {self.ano}")

# %% [markdown]
# #### 9.2 Instanciando Objetos da Classe "Carro"
# Criar um objeto a partir da classe é chamado de instanciação. A classe é vista como um esqueleto virtual, a partir da qual a instanciação cria uma entidade na memória a partir do esqueleto descrito pela classe, ou seja, um objeto.

# %%
# Criando objetos (instâncias da classe Carro)
carro1 = Carro("Fiat", "Argo", 2025)
carro2 = Carro("Ford", "Territory", 2026)

# Acessando métodos e atributos
carro1.exibir_info()  # mostra os dados do objeto 'carro1"
carro1.acelerar()     # acelera o objeto 'carro1" para a veloc. 10 km/h
carro1.acelerar()     # acelera o objeto 'carro1" para a veloc. 20 km/h
carro2.exibir_info()  # mostra os dados do objeto 'carro2"
# Out:
# Carro: Fiat Argo, Ano: 2025
# O Argo acelerou para 10 km/h
# O Argo acelerou para 20 km/h
# Carro: Ford Territory, Ano: 2026

# %% [markdown]
# #### 9.3 Conceitos da POO em Python
# * `self`: Representa a própria instância do objeto que está sendo manipulado. Ele é usado para acessar os atributos e métodos da classe.
# * `__init__`: Método especial, **construtor** do objeto, chamado automaticamente quando um novo objeto é criado, servindo para inicializar os atributos.
# * Métodos: Funções definidas na classe, e que descrevem os comportamentos do objeto.
#
# **Exemplo**
# Conta Bancária: Classe para gerenciar estados, tal como **saldo da conta bancária**.

# %%
class ContaBancaria:
    """ Classe para controle de saldo em conta bancária não remunerada
        Atributos: titular, saldo
        Métodos:   depositar, sacar (mostra o saldo final após saque, se permitido)
    """
    def __init__(self, titular, saldo_inicial=0):
        self.titular = titular
        self.saldo = saldo_inicial

    def depositar(self, valor):
        self.saldo += valor
        print(f"Depósito de R$ {valor:.2f} realizado. Saldo atual: R$ {self.saldo:8.2f}")

    def sacar(self, valor):
        if valor <= self.saldo:
            self.saldo -= valor
            print(f"Saque de R$ {valor:.2f} realizado.    Saldo atual: R$ {self.saldo:8.2f}")
        else:
            print("Saldo insuficiente!")

# Uso da clasee ContaBancaria (instanciação de objeto)
minha_conta = ContaBancaria("João", 1000)
minha_conta.depositar(500)
minha_conta.sacar(700)
minha_conta.sacar(1000)
# Out:
# Depósito de R$ 500.00 realizado. Saldo atual: R$  1500.00
# Saque de R$ 700.00 realizado.    Saldo atual: R$   800.00
# Saldo insuficiente!

# %% [markdown]
# #### 9.4 Boas Práticas
# * **Documentação**: Utilize `docstrings` para explicar a classe e seus métodos.
# * **Nomenclatura**: Nomes de classe em PascalCase (ex: MinhaClasse), métodos e variáveis em *snake_case* (ex: nome_variavel).
# * **Método __str__**: Defina o método `__str__` para retornar uma string legível sobre o objeto, útil para o comando `print()`.
#
# **Docstrings em Python**: são strings literais usadas para documentar módulos, funções, classes ou métodos, sendo colocadas logo abaixo da definição, utilizando três aspas duplas ("""). Diferente de comentários, elas persistem em tempo de execução, permitindo o uso da função `help()` e ferramentas automáticas para gerar documentação técnica.

# %% [markdown]
# ### 10 - Arquivos de Dados

# %% [markdown]
# A manipulação de arquivos de dados (persistência de dados) é um dos aspectos fundamentais na programação em Python, permitindo que *scripts* leiam, escrevam dados de forma segura.
#
# #### 10.1 Manipulação de Arquivos de Dados
# A forma mais comum de trabalhar com arquivos de dados é usando a função `open()`, que abre um arquivo e retorna um objeto da classe `File`. É altamente recomendável usar a instrução `with`, pois ela garante que o arquivo seja fechado automaticamente após o seu uso.
#
# #### 10.2 Principais Modos de Abertura de um Arquivo de Dados:
# * `'r'` (Ler): Abre para leitura (padrão). O arquivo deve existir, caso contrário um erro será indicado.
# * `'w'` (Escrever): Abre para escrita (gravação) de dados. Cria o arquivo se ele não existir, ou apaga o seu conteúdo se ele já existir.
# * `'a'` (Anexar): Abre para adicionar dados ao final do arquivo, sem apagar o seu conteúdo existente.
# * `'b'` (Binário): Usado para arquivos não-texto (imagens, áudios, vídeos etc.).
#
# Os modos de abertura podem ser combinados, tais como: `'rb'` para abrir arquivo bináro para leitura, ou `'wb'` para abrir arquivo binário para gravação.

# %% [markdown]
# #### 10.3 Exemplo de Manipulação de Arquivo de Dados: modo "iniciante"

# %%
# Exemplo de abertura de arquivo de dados no modo Escrita (se o arquivo já existir então ele será apagado)
arquivo = open('exemplo.txt', 'w', encoding='utf-8')
arquivo.write('Oi pessoal!')
arquivo.close()

# Exemplo de abertura de arquivo de dados no modo Leitura
arquivo = open('exemplo.txt', 'r', encoding='utf-8')
conteudo = arquivo.read()    # leitura de todo o conteúdo do arquivo de dados. readline() lê uma linha do arquivo de dados
arquivo.close()
print(conteudo)
# Out:
# Oi pessoal!

# %% [markdown]
# #### 10.4 Exemplo de Manipulação de Arquivo de Dados: modo "avançado"
# Usando o comando `with` que faz o fechamento automático do arquivo depois da manipulação (escrita ou leitura) dos dados do arquivo.

# %%
# Exemplo abertura de arquivo de dados no modo de Escrita
with open('novo_exemplo.txt', 'w', encoding='utf-8') as arquivo:
    arquivo.write('Oi pessoal, sejam bem-vindos!')

# Exemplo de abertura de arquivo de dados no modo de Leitura
with open('novo_exemplo.txt', 'r', encoding='utf-8') as arquivo:
    conteudo = arquivo.read()
print(conteudo)
# Out:
# Oi pessoal, sejam bem-vindos!

# %% [markdown]
# #### 10.5 Boas Práticas de Programação
# * Use `with`: Automatiza o fechamento do arquivo, evitando corrupção de dados no mesmo.
# * Defina `encoding='utf-8'`: Garante a correta leitura de caracteres especiais (símbolos).
# * Trate erros específicos: Use `except` para erros mais prováveis (ex: `FileNotFoundError`) em vez de `except` genéricos.

# %% [markdown]
# #### 10.6 Principais Métodos
# * `open()`: Função nativa para abrir arquivo.
# * `read()`, `readline()`, `readlines()`: Métodos para leitura de conteúdo do arquivo.
# * `write()`: Método para gravar texto no arquivo.
# * `try-except-finally`: Estrutura para tratamento de erros de execução do *script*.
# * `os / pathlib`: São módulos com vários métodos usados no gerenciamento de arquivos (renomear, excluir, copiar,...).
# * `pandas`: Pacote (biblioteca) eficiente para manipulação de arquivos de dados (CSV, Excel).

# %% [markdown]
# ### 11. Exercício Final

# %% [markdown]
# Criar em Python o <b>Jogo de Advinhação de um Número Inteiro, entre 1 e 100</b>, com as seguintes entradas e saídas:
#
#     Estou pensando em um número!
#     Tente adivinhar o número em que estou pensando: 25
#
#     Muito baixo! Adivinhe novamente: 50
#     Muito alto! Adivinhe novamente:  42
#
#     É isso! Você acertou!
#     Quer jogar novamente? (sim/não) não
#     Obrigado por jogar!

# %% [markdown]
# ### <span style="color: red;">12. Pacote Numpy</span>

# %% [markdown]
# #### <span style="color: blue;">12.1 Função ODEINT</span>

# %% [markdown]
# Usada para solucionar EDO's (Equações Diferenciais Ordinárias) com o método LSODA da biblioteca **odepack** do FORTRAN. Essa função faz parte do módulo `integrate` do pacote `Scipy` e requer três parâmetros:
#
# `y = odeint(modelo, y0, t)`
#
# - **modelo**: nome da função que retorna valores da derivada para os valores 'y' e 't' solicitados, $dy(t)/dt$
# - **y0**: condições iniciais do estado inicial do sistema, $y(0)$
# - **t**: pontos do tempo, para os quais a solução da EDO será calculada. Pontos internos adicionais são frequentemente calculados para manter a precisão da solução, mas não são reportados.
#
# **Exemplo 1**:  Qual é a **solução homogênea** da equação diferencial de primeira ordem $dy(t)/dt + k.y(t) = 4.x(t)$ com parâmetro $k=0.3$ e condição inicial $y(0)=5$.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def modelo(y, t):            # funcao que retorna dy(t)/dt
    k = 0.3
    dydt = -k * y
    return dydt
    
y0 = 5                       # condicao inicial
t = np.linspace(0, 20)       # 50 pontos (default) no tempo
y1 = odeint(modelo, y0, t)   # solução homogênea da EDO calculada pela função 'odeint()'
y2 = 5*np.exp(-0.3*t)        # solução homogênea da EDO obtida analiticamente: y0(t) = 5.exp(-0,3.t).u(t)
plt.figure(figsize=(6,3)); 
plt.plot(t,y1,'b-',lw=3,label="odeint()"); plt.plot(t,y2,'c-.',label="heurística")
plt.xlabel('t'); plt.ylabel('y(t)'); plt.legend(); plt.show()

# %% [markdown]
# **Exemplo 2**: Qual é a solução da equação diferencial $5.dy(t)/dt + y(t) = 2.u(t-10)$ com condição inicial $y(0)=1$.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def u(t):                  # sinal degrau unitario
    return 1*(t>=0)
    
def modelo(y,t):           # funcao que retorna dy/dt
    dydt = (-y + 2*u(t-10))/5.0
    return dydt
    
y0 = 1                     # condicao inicial
t = np.linspace(0,40,500)  # 500 pontos no tempo
y = odeint(modelo,y0,t)    # solução da EDO

plt.figure(figsize=(6, 3)); 
plt.plot(t, 2*u(t-10), 'b', label="entrada: $2.u(t-10)$"); plt.plot(t, y, 'r', label="saída: $y(t)$")
plt.xlabel('t'); plt.ylabel('sinais'); plt.legend(); plt.grid(True); plt.show()

# %% [markdown]
# [Curso online da Codecademy: "Learn Python 3"](https://www.codecademy.com/learn/learn-python-3)
# 14 lições com duração média de 14 h (máx. em 24 h) e sem pré-requisitos.
